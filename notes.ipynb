# %% [markdown]
# # SQL Notes

# %% [markdown]
# - In postgre SQL if the column names have spaces postgre will give you syntax error if you write them under `SELECT` statement so you need to wrap them in qutation mark like this "Source Tag".
